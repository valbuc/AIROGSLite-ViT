# %%
from PIL import Image
from src.transformations import Equalize, EqualizeIgnoreBlack, CenterCrop, Translate
from torchvision.transforms import Compose, ToTensor, RandomRotation
import matplotlib.pyplot as plt 
from src.preprocessing import crop_od_fill_if_needed

# %%
img = Image.open("data/ods/SHUF00000.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x384>

# %%
transform = Compose([
    ToTensor(),
    RandomRotation((-20, 20)),
    CenterCrop(0.5),
])
center = transform(img)

import matplotlib.pyplot as plt 
plt.imshow(center.permute(1, 2, 0))

# %%
transform = Compose([
    ToTensor(),
    Translate(1, 0.25),
    CenterCrop(0.5),
])
center = transform(img)

plt.imshow(center.permute(1, 2, 0))

# %%
transform = Compose([
    EqualizeIgnoreBlack(9, 69),
])
transform(img)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>

# %%
transform = Compose([
    Equalize(),
])
transform(img)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>
