# %%
from PIL import Image
from src.transformations import Equalize, EqualizeIgnoreBlack, CenterCrop
from torchvision.transforms import Compose, ToTensor

# %%
img = Image.open("data/ods/SHUF00001.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x384>

# %%
transform = Compose([
    ToTensor(),
    CenterCrop(0.5),
])
center = transform(img)

# %%
import matplotlib.pyplot as plt 
plt.imshow(center.permute(1, 2, 0))

# %%
transform = Compose([
    EqualizeIgnoreBlack(9, 69),
])
transform(img)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>

# %%
transform = Compose([
    Equalize(),
])
transform(img)
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>
